# %%
import json 
import re
import pandas as pd
import numpy as np
import seaborn as sns

from typing import Dict, Optional, Tuple, Iterable, List
from matplotlib import pyplot as plt
from medcat.cat import CAT
from medcat.cdb import CDB
from medcat.config import Config
from medcat.vocab import Vocab
from medcat.meta_cat import MetaCAT
from medcat.config_meta_cat import ConfigMetaCAT
from medcat.preprocessing.tokenizers import TokenizerWrapperBPE, TokenizerWrapperBERT
from tokenizers import ByteLevelBPETokenizer
from medcat.tokenizers.meta_cat_tokenizers import TokenizerWrapperBase
# Out:
# /home/jennifer/Documents/miade/venv/lib/python3.8/site-packages/medcat/cat.py:18: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
DATA_DIR = "/home/jennifer/Documents/miade-datasets/problems/metacat_problems_07mar2023"

# %% [markdown]
# ## Preprocess data
# This function processes the CSV data provided in ```miade-dataset``` into a dataframe ```[text, cui, name, start, end, <category_name>...]```

# %%
def preprocess_miade_synthetic_data(data_path, lower_case=True, prefix="p"):
    
    data = pd.read_csv(data_path)
    
    if lower_case:
        data = data.fillna('').astype(str).apply(lambda x: x.str.lower())  # all lower case
    else:
        if prefix == "p":
            data[["p_meta_relevance", "p_meta_confirmed", "p_meta_laterality"]] = data[["p_meta_relevance", "p_meta_confirmed", "p_meta_laterality"]].apply(lambda x: str(x).lower())
    
    # extract cui and name in separate columns
    data[["cui", "name"]] = data[prefix].str.extract(r"^(\d+)\s+\|\s+(.+)$")
    # remove words inside brackets e.g.(disease) 
    data["name"].replace(r"\s*\([^)]*\)", "", regex=True, inplace=True)
    data.drop(prefix, axis=1, inplace=True)
    
    # get the start and end indices of the concept inside {p ...} format
    if prefix == "p":
        p = re.compile(r"(\{p )|\}")
    elif prefix == "m":
        p = re.compile(r"(\{m )|\}")
    elif prefix == "r":
        p = re.compile(r"(\{r )|\}")
        
    start = []
    end = []
    for i in range(len(data)):
        match = [m for m in re.finditer(p, data.text.values[i])]
        if len(match) > 2:
            print("More than one concept in text, only processing first one")
        
        start.append(match[0].end() - 3)  # shift by -3
        end.append(match[1].start() - 3)
    
    data["start"] = start
    data["end"] = end
    
    # remove annotation brackets
    data["text"].replace(p, "", regex=True, inplace=True)  
    
    if prefix == "p":
        # convert labels
        data.replace("no laterality", "none", inplace=True)
        # tidy up columns
        data.rename(columns={"p_meta_relevance": "relevance", "p_meta_confirmed": "presence", "p_meta_laterality": "laterality (generic)"}, inplace=True)
        data = data[["text", "cui", "name", "start", "end", "relevance", "presence", "laterality (generic)"]]
    
    return data

# %%
df = preprocess_miade_synthetic_data(DATA_DIR + "/metacat_problems_historic.csv")

# %%
df
# Out:
#                                                     text                cui  \
# 0                      decidual endometritis from age 12           75585005
# 1                     bilateral metatarsus adductus prev  15667441000119108
# 2      crohn's disease of pylorus a few years previously           61424003
# 3          no prev hist of congenital facial nerve palsy          230542008
# 4            no prev hx accidental fusidic acid overdose          296643001
# ...                                                  ...                ...
# 10995         4 previous acute malnutrition in childhood          762497007
# 10996    nonspecific interstitial pneumonia while 24 y o          129452008
# 10997                 no pmh of oxyphilic adenocarcinoma          443261008
# 10998                  neonatal hyperglycemia previously          276557002
# 10999         intentional clonazepam overdose last 1 mth          296012007
#
#                                      name  start  end relevance   presence  \
# 0                   decidual endometritis      0   21  historic  confirmed
# 1           bilateral metatarsus adductus      0   29  historic  confirmed
# 2              crohn's disease of pylorus      0   26  historic  confirmed
# 3           congenital facial nerve palsy     16   45  historic    negated
# 4        accidental fusidic acid overdose     11   43  historic    negated
# ...                                   ...    ...  ...       ...        ...
# 10995     acute malnutrition in childhood     11   42  historic  confirmed
# 10996  nonspecific interstitial pneumonia      0   34  historic  confirmed
# 10997            oxyphilic adenocarcinoma     10   34  historic    negated
# 10998              neonatal hyperglycemia      0   22  historic  confirmed
# 10999     intentional clonazepam overdose      0   31  historic  confirmed
#
#       laterality (generic)
# 0                     none
# 1                bilateral
# 2                     none
# 3                     none
# 4                     none
# ...                    ...
# 10995                 none
# 10996                 none
# 10997                 none
# 10998                 none
# 10999                 none
#
# [11000 rows x 8 columns]

# %%
df['text'].str.len().mean()
# Out:
# 38.00836363636363

# %%
# sanity checks
for i in range(10):
    print(df.text.values[i][df.start.values[i]:df.end.values[i]])
# Out:
# decidual endometritis
# bilateral metatarsus adductus
# crohn's disease of pylorus
# congenital facial nerve palsy
# accidental fusidic acid overdose
# benign neoplasm of rib
# chronic lymphangitis
# contact granuloma of larynx
# reflux gastritis
# inflammation of spermatic cord

# %%
for i in range(10):
    print(df[["text", "start", "end", "relevance"]].iloc[i].tolist())
# Out:
# ['decidual endometritis from age 12', 0, 21, 'historic']
# ['bilateral metatarsus adductus prev', 0, 29, 'historic']
# ["crohn's disease of pylorus a few years previously", 0, 26, 'historic']
# ['no prev hist of congenital facial nerve palsy', 16, 45, 'historic']
# ['no prev hx accidental fusidic acid overdose', 11, 43, 'historic']
# ['benign neoplasm of rib last 8 months', 0, 22, 'historic']
# ['chronic lymphangitis upto age 63', 0, 20, 'historic']
# ['contact granuloma of larynx few yrs previously', 0, 27, 'historic']
# ['reflux gastritis last 1 mth', 0, 16, 'historic']
# ['prev hist inflammation of spermatic cord', 10, 40, 'historic']

# %% [markdown]
# ## Generate training data
#
# Randomly samples a number of training data and concatenates it into one training data df ready for input into the next step

# %%
config_dict = {
    "historic_path": DATA_DIR + "/metacat_problems_historic.csv",
    "suspected_path": DATA_DIR + "/metacat_problems_suspected.csv",
    "negated_path": DATA_DIR + "/metacat_problems_negated.csv",
    "irrelevant_path": DATA_DIR + "/metacat_problems_irrelevant.csv",
    "confirmed_num": 10,
    "historic_num": 10,
    "irrelevant_num": 10,
    "present_num": 10,
    "suspected_num": 10,
    "negated_num": 10}

# %%
def create_problems_training_data(config_dict):
    historic_df = preprocess_miade_synthetic_data(config_dict.get("historic_path"))
    suspected_df =  preprocess_miade_synthetic_data(config_dict.get("suspected_path"))
    irrelevant_df=  preprocess_miade_synthetic_data(config_dict.get("irrelevant_path"))
    negated_df =  preprocess_miade_synthetic_data(config_dict.get("negated_path"))
    
    historic_train = []
    suspected_train = []
    irrelevant_train = []
    negated_train = []
    
    if historic_df is not None:
        historic_train = historic_df.sample(n=config_dict["historic_num"])
    if suspected_df is not None:
        suspected_train = suspected_df.sample(n=config_dict["suspected_num"])
    if irrelevant_df is not None:
        irrelevant_train = irrelevant_df.sample(n=config_dict["irrelevant_num"])
    if negated_df is not None:
        negated_train = negated_df.sample(n=config_dict["negated_num"])
    
    train_data = pd.concat([historic_train, suspected_train, irrelevant_train, negated_train], ignore_index=True)
    print(len(train_data))
    
    return train_data

# %%
train_df = create_problems_training_data(config_dict)
# Out:
# 40

# %%
train_df
# Out:
#                                                  text                cui  \
# 0     no hist of sympathetic nervous structure injury          282747005
# 1                 agenesis of nasal bone when 30 yr o         1003577003
# 2                     previous acute skin sarcoidosis          238674006
# 3          infectious disease of abdomen last 7 month          128070006
# 4                         no ph of cannabis poisoning         1149328002
# 5                prev acute myocarditis - tuberculous          194949003
# 6          previous hx of exotropia of bilateral eyes  15632691000119105
# 7   past medical history of hypertrophy of gallbla...           76875008
# 8            laceration of right buttock last 3 month  10904511000119107
# 9                              several acute pyelitis           32801008
# 10      accidental chlorprothixene overdose suspected          427131001
# 11                    suspicion of sprain of shoulder            3199001
# 12                           pos nutritional myopathy           44253006
# 13             probably bee sting-induced anaphylaxis          241931004
# 14            apolipoprotein a-i deficiency suspected          238095002
# 15                    maybe adenocarcinoma of bladder          255110003
# 16                         possible fecal peritonitis          235985005
# 17                              suspect lymph fistula          234105001
# 18  susp microcephaly-oculo-digito-esophageal-duod...          702431004
# 19        could be primary immune deficiency disorder           58606001
# 20             explained about postsurgical menopause          371036001
# 21                 sisters primary syphilis of nipple          237447001
# 22    sibling feels infection caused by gigantocotyle           55065004
# 23                    family hist bacterial keratitis          314557000
# 24             husbands leukemic infiltration of skin          404156009
# 25             sisters has macrosaccadic oscillations          307689000
# 26          non-diabetic hypoglycemic coma risk score          230796005
# 27       discussed intentional flunitrazepam overdose          296056007
# 28              worried elephantiasis of upper eyelid          700337008
# 29     fhx heterophil-negative mononucleosis syndrome           65230006
# 30  absence of signs and symptoms of disorder of e...          609522002
# 31      traumatic intracranial subdural hematoma none          262952002
# 32                        absence of injury of finger           52011008
# 33                       denied conjunctival abrasion          609362004
# 34      intentional netilmicin poisoning not detected          291490007
# 35                          chronic peptic ulcer none          128287004
# 36            absent miscarriage complicated by shock           34270000
# 37                                   no haff syndrome          359569009
# 38  absence of signs and symptoms of disease cause...          409790005
# 39              cryptococcal chorioretinitis negative          416877003
#
#                                                  name  start  end   relevance  \
# 0                sympathetic nervous structure injury     11   47    historic
# 1                              agenesis of nasal bone      0   22    historic
# 2                              acute skin sarcoidosis      9   31    historic
# 3                       infectious disease of abdomen      0   29    historic
# 4                                  cannabis poisoning      9   27    historic
# 5                     acute myocarditis - tuberculous      5   36    historic
# 6                         exotropia of bilateral eyes     15   42    historic
# 7                          hypertrophy of gallbladder     24   50    historic
# 8                         laceration of right buttock      0   27    historic
# 9                                      acute pyelitis      8   22    historic
# 10                accidental chlorprothixene overdose      0   35     present
# 11                                 sprain of shoulder     13   31     present
# 12                               nutritional myopathy      4   24     present
# 13                      bee sting-induced anaphylaxis      9   38     present
# 14                      apolipoprotein a-i deficiency      0   29     present
# 15                          adenocarcinoma of bladder      6   31     present
# 16                                  fecal peritonitis      9   26     present
# 17                                      lymph fistula      8   21     present
# 18  microcephaly-oculo-digito-esophageal-duodenal ...      5   59     present
# 19                 primary immune deficiency disorder      9   43     present
# 20                             postsurgical menopause     16   38  irrelevant
# 21                         primary syphilis of nipple      8   34  irrelevant
# 22                  infection caused by gigantocotyle     14   47  irrelevant
# 23                                bacterial keratitis     12   31  irrelevant
# 24                      leukemic infiltration of skin      9   38  irrelevant
# 25                         macrosaccadic oscillations     12   38  irrelevant
# 26                     non-diabetic hypoglycemic coma      0   30  irrelevant
# 27                 intentional flunitrazepam overdose     10   44  irrelevant
# 28                      elephantiasis of upper eyelid      8   37  irrelevant
# 29         heterophil-negative mononucleosis syndrome      4   46  irrelevant
# 30                disorder of extraembryonic membrane     33   68     present
# 31           traumatic intracranial subdural hematoma      0   40     present
# 32                                   injury of finger     11   27     present
# 33                              conjunctival abrasion      7   28     present
# 34                   intentional netilmicin poisoning      0   32     present
# 35                               chronic peptic ulcer      0   20     present
# 36                   miscarriage complicated by shock      7   39     present
# 37                                      haff syndrome      3   16     present
# 38                        disease caused by neisseria     33   60     present
# 39                       cryptococcal chorioretinitis      0   28     present
#
#      presence laterality (generic)
# 0     negated                 none
# 1   confirmed                 none
# 2   confirmed                 none
# 3   confirmed                 none
# 4     negated                 none
# 5   confirmed                 none
# 6   confirmed            bilateral
# 7   confirmed                 none
# 8   confirmed                right
# 9   confirmed                 none
# 10  suspected                 none
# 11  suspected                 none
# 12  suspected                 none
# 13  suspected                 none
# 14  suspected                 none
# 15  suspected                 none
# 16  suspected                 none
# 17  suspected                 none
# 18  suspected                 none
# 19  suspected                 none
# 20  confirmed                 none
# 21  confirmed                 none
# 22  confirmed                 none
# 23  confirmed                 none
# 24  confirmed                 none
# 25  confirmed                 none
# 26  confirmed                 none
# 27  confirmed                 none
# 28  confirmed                 none
# 29  confirmed                 none
# 30    negated                 none
# 31    negated                 none
# 32    negated                 none
# 33    negated                 none
# 34    negated                 none
# 35    negated                 none
# 36    negated                 none
# 37    negated                 none
# 38    negated                 none
# 39    negated                 none

# %%
# save
train_df.to_csv("./problems_synthetic_train_example.csv", index=False)

# %% [markdown]
# ## Tokenize and convert to training data input
#
# Modified from the utility function prepare_from_json() from MedCAT:
# https://github.com/CogStack/MedCAT/blob/3e979951b0bf817b56445d90c6e7fcab97ef0390/medcat/utils/meta_cat/data_utils.py#L5
#
# Instead of using MedCATTrainer JSON, this function takes the preprocessed MiADE synthetic data CSV (output from ```preprocess_miade_synthetic_data()```) and converts it to output data that is ready for input into Pytorch model training, which is wrapped inside the MetaCAT ```train()``` function

# %%
def prepare_from_miade_csv(
    data: pd.DataFrame,
    category_name: str,
    cntx_left: int,
    cntx_right: int,
    tokenizer: TokenizerWrapperBase,
    replace_center: str = None,
    lowercase: bool = True,
    ) -> Dict:

    out_data: Dict = {}
    
    for i in range(len(data)):
        text = data.text.values[i]
            
        if len(text) > 0:
            doc_text = tokenizer(text)
        
            start = data.start.values[i]
            end = data.end.values[i]

            # Get the index of the center token
            ind = 0
            for ind, pair in enumerate(doc_text['offset_mapping']):
                if start >= pair[0] and start < pair[1]:
                    break

            _start = max(0, ind - cntx_left)
            _end = min(len(doc_text['input_ids']), ind + 1 + cntx_right)
            tkns = doc_text['input_ids'][_start:_end]
            cpos = cntx_left + min(0, ind-cntx_left)
            
            if replace_center is not None:
                if lowercase:
                    replace_center = replace_center.lower()
                for p_ind, pair in enumerate(doc_text['offset_mapping']):
                    if start >= pair[0] and start < pair[1]:
                        s_ind = p_ind
                    if end > pair[0] and end <= pair[1]:
                        e_ind = p_ind

                ln = e_ind - s_ind
                tkns = tkns[:cpos] + tokenizer(replace_center)['input_ids'] + tkns[cpos+ln+1:]
            
            value = data[category_name].values[i]
            sample = [tkns, cpos, value]

            if category_name in out_data:
                out_data[category_name].append(sample)
            else:
                out_data[category_name] = [sample]
    
    return out_data

# %%
# example tokenizer
mc = MetaCAT.load("./data/Status")

# %%
prepare_from_miade_csv(train_df, category_name="presence", cntx_left=5, cntx_right=8, tokenizer=mc.tokenizer, replace_center="disease")
# Out:
# {'presence': [[[1547, 11292, 313, 8506], 3, 'negated'],
#   [[8506, 1132, 950, 6186, 290], 0, 'confirmed'],
#   [[5500, 8506], 1, 'confirmed'],
#   [[8506, 645, 464, 3015], 0, 'confirmed'],
#   [[1547, 1051, 313, 8506], 3, 'negated'],
#   [[1396, 85, 8506], 2, 'confirmed'],
#   [[5500, 2430, 313, 8506], 3, 'confirmed'],
#   [[3564, 702, 682, 313, 8506], 4, 'confirmed'],
#   [[8506, 645, 373, 3015], 0, 'confirmed'],
#   [[11946, 8506], 1, 'confirmed'],
#   [[8506, 7074], 0, 'suspected'],
#   [[28577, 313, 8506], 2, 'suspected'],
#   [[1218, 8506], 1, 'suspected'],
#   [[13910, 8506], 1, 'suspected'],
#   [[8506, 7074], 0, 'suspected'],
#   [[9181, 3998, 8506], 2, 'suspected'],
#   [[6606, 8506], 1, 'suspected'],
#   [[25626, 8506], 1, 'suspected'],
#   [[13481, 8506], 1, 'suspected'],
#   [[11405, 429, 8506], 2, 'suspected'],
#   [[15629, 2486, 8506], 2, 'confirmed'],
#   [[12351, 82, 8506], 2, 'confirmed'],
#   [[18258, 6144, 8506], 2, 'confirmed'],
#   [[3028, 11292, 8506], 2, 'confirmed'],
#   [[9127, 21684, 8506], 2, 'confirmed'],
#   [[12351, 82, 604, 8506], 3, 'confirmed'],
#   [[8506, 2738, 10192], 0, 'confirmed'],
#   [[10246, 8506], 1, 'confirmed'],
#   [[6479, 6867, 8506], 2, 'confirmed'],
#   [[69, 9194, 8506], 2, 'confirmed'],
#   [[313, 1371, 308, 2995, 313, 8506], 5, 'negated'],
#   [[8506, 1700], 0, 'negated'],
#   [[28925, 313, 8506], 2, 'negated'],
#   [[18919, 8506], 1, 'negated'],
#   [[8506, 390, 6553], 0, 'negated'],
#   [[8506, 1700], 0, 'negated'],
#   [[17808, 8506], 1, 'negated'],
#   [[1547, 8506], 1, 'negated'],
#   [[313, 1371, 308, 2995, 313, 8506], 5, 'negated'],
#   [[8506, 1310], 0, 'negated']]}
